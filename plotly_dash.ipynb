# %%
# Import required libraries
import pandas as pd
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.express as px

# %%
# Read the dataset
spacex_df = pd.read_csv("spacex.csv")

# %%
spacex_df.columns
# Out:
# Index(['Unnamed: 0', 'FlightNumber', 'Date', 'BoosterVersion', 'PayloadMass',
#        'Orbit', 'LaunchSite', 'Outcome', 'Flights', 'GridFins', 'Reused',
#        'Legs', 'LandingPad', 'Block', 'ReusedCount', 'Serial', 'Longitude',
#        'Latitude', 'Class', 'Year'],
#       dtype='object')

# %%
# Get min and max payload
min_payload = spacex_df['PayloadMass'].min()
max_payload = spacex_df['PayloadMass'].max()

# %%
# Create Dash app
app = dash.Dash(__name__)

# App layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dashboard',
            style={'textAlign': 'center'}),

    # ---------------- TASK 1 ----------------
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
        ],
        value='ALL',
        placeholder="Select a Launch Site",
        searchable=True
    ),

    html.Br(),

    # Pie chart
    html.Div(dcc.Graph(id='success-pie-chart')),

    html.Br(),

    html.P("Payload range (Kg):"),

    # ---------------- TASK 3 ----------------
    dcc.RangeSlider(
        id='payload-slider',
        min=0,
        max=10000,
        step=1000,
        marks={0: '0', 2500: '2500', 5000: '5000', 7500: '7500', 10000: '10000'},
        value=[min_payload, max_payload]
    ),

    html.Br(),

    # Scatter plot
    html.Div(dcc.Graph(id='success-payload-scatter-chart'))
])

# ---------------- TASK 2 ----------------
@app.callback(
    Output('success-pie-chart', 'figure'),
    Input('site-dropdown', 'value')
)
def update_pie_chart(selected_site):
    if selected_site == 'ALL':
        fig = px.pie(
            spacex_df,
            names='Launch Site',
            values='class',
            title='Total Successful Launches by Site'
        )
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == selected_site]
        fig = px.pie(
            filtered_df,
            names='class',
            title=f'Success vs Failure for {selected_site}'
        )
    return fig


# ---------------- TASK 4 ----------------
@app.callback(
    Output('success-payload-scatter-chart', 'figure'),
    [Input('site-dropdown', 'value'),
     Input('payload-slider', 'value')]
)
def update_scatter(selected_site, payload_range):

    low, high = payload_range
    filtered_df = spacex_df[
        (spacex_df['Payload Mass (kg)'] >= low) &
        (spacex_df['Payload Mass (kg)'] <= high)
    ]

    if selected_site != 'ALL':
        filtered_df = filtered_df[
            filtered_df['Launch Site'] == selected_site
        ]

    fig = px.scatter(
        filtered_df,
        x='Payload Mass (kg)',
        y='class',
        color='Booster Version Category',
        title='Payload vs Launch Outcome'
    )

    return fig

# %%
# Run the app
if __name__ == '__main__':
    app.run()
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# [2026-02-11 20:54:22,580] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\pandas\core\indexes\base.py", line 3812, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7088, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7096, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'Payload Mass (kg)'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\flask\app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\dash\_get_app.py", line 17, in wrap
#     return ctx.run(func, self, *args, **kwargs)
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\dash\dash.py", line 1600, in dispatch
#     response_data = ctx.run(partial_func)
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\dash\_callback.py", line 720, in add_context
#     raise err
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\dash\_callback.py", line 711, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)  # type: ignore[reportArgumentType]
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\dash\_callback.py", line 58, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "C:\Users\MT\AppData\Local\Temp\ipykernel_10492\2227799372.py", line 82, in update_scatter
#     (spacex_df['Payload Mass (kg)'] >= low) &
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\pandas\core\frame.py", line 4113, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\pandas\core\indexes\base.py", line 3819, in get_loc
#     raise KeyError(key) from err
# KeyError: 'Payload Mass (kg)'
# [2026-02-11 20:54:23,020] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\flask\app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\dash\_get_app.py", line 17, in wrap
#     return ctx.run(func, self, *args, **kwargs)
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\dash\dash.py", line 1600, in dispatch
#     response_data = ctx.run(partial_func)
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\dash\_callback.py", line 720, in add_context
#     raise err
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\dash\_callback.py", line 711, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)  # type: ignore[reportArgumentType]
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\dash\_callback.py", line 58, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "C:\Users\MT\AppData\Local\Temp\ipykernel_10492\2227799372.py", line 56, in update_pie_chart
#     fig = px.pie(
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\plotly\express\_chart_types.py", line 1721, in pie
#     return make_figure(
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\plotly\express\_core.py", line 2511, in make_figure
#     args = build_dataframe(args, constructor)
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\plotly\express\_core.py", line 1757, in build_dataframe
#     df_output, wide_id_vars = process_args_into_dataframe(
#   File "c:\Users\MT\Desktop\Python2\venv\lib\site-packages\plotly\express\_core.py", line 1358, in process_args_into_dataframe
#     raise ValueError(err_msg)
# ValueError: Value of 'names' is not the name of a column in 'data_frame'. Expected one of ['Unnamed: 0', 'FlightNumber', 'Date', 'BoosterVersion', 'PayloadMass', 'Orbit', 'LaunchSite', 'Outcome', 'Flights', 'GridFins', 'Reused', 'Legs', 'LandingPad', 'Block', 'ReusedCount', 'Serial', 'Longitude', 'Latitude', 'Class', 'Year'] but received: Launch Site
